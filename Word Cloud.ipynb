# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from nltk.corpus import stopwords
import numpy as np
from PIL import Image
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
WCD = dict()
def MakeCloud(text , title = 'Word Clouds' , w = 15 , h = 15):
    global WCD
    plt.figure(figsize=(w,h))
    WC = WordCloud(background_color="white",stopwords=set(stopwords.words('english'))).generate("".join([i.lower() for i in text.split()]))
    WCD = WC.words_
    plt.imshow(WC)
    plt.axis("off")
    plt.title(title)
    plt.show()

# %%
f = open("/content/ww2.txt", "r",  encoding='utf-8')
Text = f.read()
MakeCloud(Text)

# %%
WCD
# Out:
# {'mainarticle': 1.0,
#  'china': 0.7142857142857143,
#  'france': 0.7142857142857143,
#  'theunitedkingdom': 0.7142857142857143,
#  'germany': 0.7142857142857143,
#  'japan': 0.5714285714285714,
#  'thesovietunion': 0.5714285714285714,
#  'meanwhile': 0.5714285714285714,
#  'however': 0.5714285714285714,
#  'theunitedstates': 0.5714285714285714,
#  'soonafter': 0.5714285714285714,
#  'inmid': 0.5714285714285714,
#  'disambiguation': 0.42857142857142855,
#  'australia': 0.42857142857142855,
#  'italy': 0.42857142857142855,
#  'atthesametime': 0.42857142857142855,
#  'british': 0.42857142857142855,
#  'offensive': 0.42857142857142855,
#  'initaly': 0.42857142857142855,
#  'wwii': 0.2857142857142857,
#  'pacific': 0.2857142857142857,
#  'mediterranean': 0.2857142857142857,
#  '000civiliandead': 0.2857142857142857,
#  '000totaldead': 0.2857142857142857,
#  'massacres': 0.2857142857142857,
#  'underthemolotov': 0.2857142857142857,
#  'spheresofinfluence': 0.2857142857142857,
#  'simultaneousoffensivesagainstsoutheastasiaandthecentralpacific': 0.2857142857142857,
#  'alliedvictory': 0.2857142857142857,
#  'concentrationcamps': 0.2857142857142857,
#  'hungary': 0.2857142857142857,
#  'romania': 0.2857142857142857,
#  'inmarch1938': 0.2857142857142857,
#  'instead': 0.2857142857142857,
#  'soviet': 0.2857142857142857,
#  'ron': 0.2857142857142857,
#  'war': 0.2857142857142857,
#  'ribbentroppact': 0.2857142857142857,
#  'estonia': 0.2857142857142857,
#  'latviaandlithuania': 0.2857142857142857,
#  'operation': 0.2857142857142857,
#  'westerneurope': 0.2857142857142857,
#  'worldwarii': 0.2857142857142857,
#  'easternfront': 0.2857142857142857,
#  'bycontrast': 0.2857142857142857,
#  'bymid': 0.2857142857142857,
#  'japanese': 0.2857142857142857,
#  'unitedkingdom': 0.2857142857142857,
#  'inmay1943': 0.2857142857142857,
#  'inburma': 0.2857142857142857,
#  'inthepacifictheatre': 0.2857142857142857,
#  'november': 0.2857142857142857,
#  'innorthafrica': 0.2857142857142857,
#  'equipment': 0.2857142857142857,
#  'franklind': 0.2857142857142857,
#  'day': 0.2857142857142857,
#  'inseptember1944': 0.2857142857142857,
#  'post': 0.2857142857142857,
#  'eastgermany': 0.2857142857142857,
#  'inasia': 0.2857142857142857,
#  'homosexuals': 0.2857142857142857,
#  'genocide': 0.2857142857142857,
#  'bytheendofthewar': 0.2857142857142857,
#  'anti': 0.2857142857142857,
#  'citationneeded': 0.2857142857142857,
#  'worldwariifromwikipedia': 0.14285714285714285,
#  'thefreeencyclopediajumptonavigationjumptosearch': 0.14285714285714285,
#  'thesecondworldwar': 0.14285714285714285,
#  'aircraftplayedamajorroleintheconflict': 0.14285714285714285,
#  'enablingthestrategicbombingofpopulationcentresandtheonlytwousesofnuclearweaponsinwartothisday': 0.14285714285714285,
#  'worldwariiwasbyfarthedeadliestconflictinhumanhistory': 0.14285714285714285,
#  'itresultedin70to85millionfatalities': 0.14285714285714285,
#  'amajoritybeingcivilians': 0.14285714285714285,
#  'tensofmillionsofpeoplediedduetogenocides': 0.14285714285714285,
#  'includingtheholocaust': 0.14285714285714285,
#  'starvation': 0.14285714285714285,
#  'anddisease': 0.14285714285714285,
#  'inthewakeoftheaxisdefeat': 0.14285714285714285,
#  'germanyandjapanwereoccupied': 0.14285714285714285,
#  'andwarcrimestribunalswereconductedagainstgermanandjapaneseleaders': 0.14285714285714285,
#  'worldwariiisgenerallyconsideredtohavebegunon1september1939': 0.14285714285714285,
#  'whennazigermany': 0.14285714285714285,
#  'underadolfhitler': 0.14285714285714285,
#  'invadedpoland': 0.14285714285714285,
#  'theunitedkingdomandfrancesubsequentlydeclaredwarongermanyonthe3rdofseptember': 0.14285714285714285,
#  'ribbentroppactofaugust1939': 0.14285714285714285,
#  'germanyandthesovietunionhadpartitionedpolandandmarkedouttheir': 0.14285714285714285,
#  'acrossfinland': 0.14285714285714285,
#  'romaniaandthebalticstates': 0.14285714285714285,
#  'fromlate1939toearly1941': 0.14285714285714285,
#  'inaseriesofcampaignsandtreaties': 0.14285714285714285,
#  'germanyconqueredorcontrolledmuchofcontinentaleurope': 0.14285714285714285,
#  'andformedtheaxisalliancewithitalyandjapan': 0.14285714285714285,
#  'alongwithothercountrieslateron': 0.14285714285714285,
#  'followingtheonsetofcampaignsinnorthafricaandeastafrica': 0.14285714285714285,
#  'andthefalloffranceinmid': 0.14285714285714285,
#  'thewarcontinuedprimarilybetweentheeuropeanaxispowersandthebritishempire': 0.14285714285714285,
#  'withwarinthebalkans': 0.14285714285714285,
#  'theaerialbattleofbritain': 0.14285714285714285,
#  'theblitzoftheuk': 0.14285714285714285,
#  'andthebattleoftheatlantic': 0.14285714285714285,
#  'on22june1941': 0.14285714285714285,
#  'germanyledtheeuropeanaxispowersinaninvasionofthesovietunion': 0.14285714285714285,
#  'openingtheeasternfront': 0.14285714285714285,
#  'thelargestlandtheatreofwarinhistoryandtrappingtheaxispowers': 0.14285714285714285,
#  'cruciallythegermanwehrmacht': 0.14285714285714285,
#  'inawarofattrition': 0.14285714285714285,
#  'whichaimedtodominateasiaandthepacific': 0.14285714285714285,
#  'wasatwarwiththerepublicofchinaby1937': 0.14285714285714285,
#  'indecember1941': 0.14285714285714285,
#  'japanattackedamericanandbritishterritorieswithnear': 0.14285714285714285,
#  'includinganattackontheusfleetatpearlharborwhichforcedtheustodeclarewaragainstjapan': 0.14285714285714285,
#  'theeuropeanaxispowersdeclaredwarontheusinsolidarity': 0.14285714285714285,
#  'japansooncapturedmuchofthewesternpacific': 0.14285714285714285,
#  'butitsadvanceswerehaltedin1942afterlosingthecriticalbattleofmidway': 0.14285714285714285,
#  'later': 0.14285714285714285,
#  'germanyanditalyweredefeatedinnorthafricaandatstalingradinthesovietunion': 0.14285714285714285,
#  'keysetbacksin1943': 0.14285714285714285,
#  'includingaseriesofgermandefeatsontheeasternfront': 0.14285714285714285,
#  'thealliedinvasionsofsicilyandtheitalianmainland': 0.14285714285714285,
#  'andalliedoffensivesinthepacific': 0.14285714285714285,
#  'costtheaxispowerstheirinitiativeandforceditintostrategicretreatonallfronts': 0.14285714285714285,
#  'in1944': 0.14285714285714285,
#  'thewesternalliesinvadedgerman': 0.14285714285714285,
#  'occupiedfrance': 0.14285714285714285,
#  'whilethesovietunionregaineditsterritoriallossesandturnedtowardsgermanyanditsallies': 0.14285714285714285,
#  'during1944and1945': 0.14285714285714285,
#  'japansufferedreversalsinmainlandasia': 0.14285714285714285,
#  'whilethealliescrippledthejapanesenavyandcapturedkeywesternpacificislands': 0.14285714285714285,
#  'thewarineuropeconcludedwiththeliberationofgerman': 0.14285714285714285,
#  'occupiedterritories': 0.14285714285714285,
#  'andtheinvasionofgermanybythewesternalliesandthesovietunion': 0.14285714285714285,
#  'culminatinginthefallofberlintosoviettroops': 0.14285714285714285,
#  "hitler'ssuicideandthegermanunconditionalsurrenderon8may1945": 0.14285714285714285,
#  'followingthepotsdamdeclarationbytheallieson26july1945andtherefusalofjapantosurrenderonitsterms': 0.14285714285714285,
#  'theunitedstatesdroppedthefirstatomicbombsonthejapanesecitiesofhiroshima': 0.14285714285714285,
#  'on6august': 0.14285714285714285,
#  'andnagasaki': 0.14285714285714285,
#  'on9august': 0.14285714285714285,
#  'facedwithanimminentinvasionofthejapanesearchipelago': 0.14285714285714285,
#  'thepossibilityofadditionalatomicbombings': 0.14285714285714285,
#  'andthesovietentryintothewaragainstjapananditsinvasionofmanchuria': 0.14285714285714285,
#  'japanannounceditsintentiontosurrenderon15august': 0.14285714285714285,
#  'thensignedthesurrenderdocumenton2september1945': 0.14285714285714285,
#  'cementingtotalvictoryinasiafortheallies': 0.14285714285714285,
#  'worldwariichangedthepoliticalalignmentandsocialstructureoftheglobe': 0.14285714285714285,
#  'theunitednations': 0.14285714285714285,
#  'un': 0.14285714285714285,
#  'wasestablishedtofosterinternationalco': 0.14285714285714285,
#  'operationandpreventfutureconflicts': 0.14285714285714285,
#  'andthevictoriousgreatpowers': 0.14285714285714285}

# %%
f = open("/content/mars.txt", "r",  encoding='utf-8')
Text = f.read()
MakeCloud(Text)

# %%
WCD
# Out:
# {'c': 1.0,
#  'f': 0.8333333333333334,
#  'mars': 0.8333333333333334,
#  '2mi': 0.8333333333333334,
#  'h': 0.6666666666666666,
#  'however': 0.6666666666666666,
#  'indiameter': 0.6666666666666666,
#  '000years': 0.6666666666666666,
#  'canals': 0.5,
#  'forexample': 0.5,
#  '8kilometres': 0.5,
#  'deep': 0.5,
#  'anddeimos': 0.5,
#  'martian': 0.5,
#  'b 1mi': 0.5,
#  'seemars': 0.3333333333333333,
#  '1mi': 0.3333333333333333,
#  '1km': 0.3333333333333333,
#  's2': 0.3333333333333333,
#  'inenglish': 0.3333333333333333,
#  'redplanet': 0.3333333333333333,
#  'thatofearth': 0.3333333333333333,
#  'on24september2014': 0.3333333333333333,
#  'isro': 0.3333333333333333,
#  'whichislessthan1': 0.3333333333333333,
#  '36ft': 0.3333333333333333,
#  'ora': 0.3333333333333333,
#  'iii': 0.3333333333333333,
#  'brown': 0.3333333333333333,
#  '3and2': 0.3333333333333333,
#  'metre': 0.3333333333333333,
#  'high': 0.3333333333333333,
#  '300ft': 0.3333333333333333,
#  'sodium': 0.3333333333333333,
#  'mro': 0.3333333333333333,
#  '12mi': 0.3333333333333333,
#  'latitude': 0.3333333333333333,
#  'across': 0.3333333333333333,
#  'rockand': 0.3333333333333333,
#  'ofwaterice': 0.3333333333333333,
#  '000kilometres': 0.3333333333333333,
#  '9mi': 0.3333333333333333,
#  'meridianbay': 0.3333333333333333,
#  'mountolympus': 0.3333333333333333,
#  'n180': 0.3333333333333333,
#  'n0': 0.3333333333333333,
#  'e': 0.3333333333333333,
#  'mainarticle': 0.3333333333333333,
#  '5mi': 0.3333333333333333,
#  '2001marsodyssey': 0.3333333333333333,
#  'comparedtoearth': 0.3333333333333333,
#  '7mi': 0.3333333333333333,
#  'carbondioxide': 0.3333333333333333,
#  'citationneeded': 0.3333333333333333,
#  'like': 0.3333333333333333,
#  'asaresult': 0.3333333333333333,
#  '143millionmi': 0.3333333333333333,
#  'thus': 0.3333333333333333,
#  'clo4': 0.3333333333333333,
#  'phobos': 0.3333333333333333,
#  'moon': 0.3333333333333333,
#  'marsorbitermission': 0.3333333333333333,
#  '1lander': 0.3333333333333333,
#  'in1610': 0.3333333333333333,
#  'telescope': 0.3333333333333333,
#  'intelligent': 0.3333333333333333,
#  'g': 0.3333333333333333,
#  '8km': 0.3333333333333333,
#  'exceptatthelowestelevationsforshortperiods thetwopolaricecapsappeartobemadelargelyofwater': 0.3333333333333333,
#  'thetwopolaricecapsappeartobemadelargelyofwater thevolumeofwatericeinthesouthpolaricecap': 0.3333333333333333,
#  'thevolumeofwatericeinthesouthpolaricecap ifmelted': 0.3333333333333333,
#  '600by8 500kilometres': 0.3333333333333333,
#  '500kilometres 600by5': 0.3333333333333333,
#  '600by5 300mi': 0.3333333333333333,
#  'earth days': 0.3333333333333333,
#  'landers androvers': 0.3333333333333333,
#  'marsfromwikipedia': 0.16666666666666666,
#  'thefreeencyclopediajumptonavigationjumptosearchthisarticleisabouttheplanet': 0.16666666666666666,
#  'forthedeity': 0.16666666666666666,
#  'mythology': 0.16666666666666666,
#  'forotheruses': 0.16666666666666666,
#  'disambiguation': 0.16666666666666666,
#  'marsastronomicalsymbolofmarsmarsappearsasared': 0.16666666666666666,
#  'orangeglobewithdarkerblotchesandwhiteicecapsvisibleonbothofitspoles': 0.16666666666666666,
#  'picturedinnaturalcolorin2007': 0.16666666666666666,
#  'designationspronunciation': 0.16666666666666666,
#  'ˈmɑːrz': 0.16666666666666666,
#  'aboutthissoundlisten': 0.16666666666666666,
#  'adjectivesmartian': 0.16666666666666666,
#  'ˈmɑːrʃən': 0.16666666666666666,
#  'orbitalcharacteristics': 0.16666666666666666,
#  'epochj2000aphelion249200000km': 0.16666666666666666,
#  '154800000mi': 0.16666666666666666,
#  '666au': 0.16666666666666666,
#  'perihelion206700000km': 0.16666666666666666,
#  '128400000mi': 0.16666666666666666,
#  '382au': 0.16666666666666666,
#  'semi': 0.16666666666666666,
#  'majoraxis227939200km': 0.16666666666666666,
#  'apparentmagnitude': 0.16666666666666666,
#  '94to': 0.16666666666666666,
#  'angulardiameter3': 0.16666666666666666,
#  'atmosphere': 0.16666666666666666,
#  'surfacepressure0': 0.16666666666666666,
#  'kpa0': 0.16666666666666666,
#  '00628atmcompositionbyvolume95': 0.16666666666666666,
#  'carbondioxide1': 0.16666666666666666,
#  'argon1': 0.16666666666666666,
#  'nitrogen0': 0.16666666666666666,
#  'oxygen0': 0.16666666666666666,
#  'carbonmonoxide0': 0.16666666666666666,
#  'watervapor0': 0.16666666666666666,
#  'nitrogenoxide0': 0.16666666666666666,
#  'neon0': 0.16666666666666666,
#  'hydrogendeuteriumoxide0': 0.16666666666666666,
#  'krypton0': 0.16666666666666666,
#  'xenonmarsisthefourthplanetfromthesunandthesecond': 0.16666666666666666,
#  'smallestplanetinthesolarsystem': 0.16666666666666666,
#  'beinglargerthanonlymercury': 0.16666666666666666,
#  'marscarriesthenameoftheromangodofwarandisoftenreferredtoasthe': 0.16666666666666666,
#  "thelatterreferstotheeffectoftheironoxideprevalentonmars'ssurface": 0.16666666666666666}

# %%
def MaskCloud(Text,ImagePath,SaveImage,Width) :
    ThisMask = np.array(Image.open(ImagePath))
    ThisMask = ThisMask[:,:,0]
    def transform_format(val):
        if val == 0:
            return 255
        else:
            return val
    TransformedThisMask = np.ndarray((ThisMask.shape[0],ThisMask.shape[1]), np.int32)
    for i in range(len(ThisMask)):
        TransformedThisMask[i] = list(map(transform_format, ThisMask[i]))
    wc = WordCloud(background_color="white", max_words=1000, mask=TransformedThisMask,
                    contour_width=Width, contour_color='firebrick')
    wc.generate(Text)
    wc.to_file(SaveImage)
    plt.figure(figsize=[20,10])
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    return None

# %%
f = open("/content/civil.txt", "r",  encoding='utf-8')
Text = f.read()
MaskCloud(Text,'/content/0.jpg','Cloud Image.jpg',2)

# %%
MaskCloud(Text,'0.jpg','Cloud Image.jpg',0)

# %%
# !pip install wordcloud-fa -qqq
# !pip install arabic_reshaper

from arabic_reshaper import arabic_reshaper
from wordcloud_fa import WordCloudFa
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.7/316.7 kB 35.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for nltk (setup.py) ... done
#   Building wheel for libwapiti (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Requirement already satisfied: arabic_reshaper in /usr/local/lib/python3.10/dist-packages (3.0.0)

# %%
def MakeCloud(text,Width=1,title = 'Word Clouds',w = 15,h = 15) :
    ImagePath = '/content/TwitterLogo.jpg'
    ThisMask = np.array(Image.open(ImagePath))
    ThisMask = ThisMask[:,:,0]
    def transform_format(val):
        if val == 0:
            return 255
        else:
            return val
    TransformedThisMask = np.ndarray((ThisMask.shape[0],ThisMask.shape[1]), np.int32)
    for i in range(len(ThisMask)):
        TransformedThisMask[i] = list(map(transform_format, ThisMask[i]))
    plt.figure(figsize=(w,h))
    wc = WordCloudFa(persian_normalize=True, no_reshape=True, background_color="white", width=1000, height=500,mask =TransformedThisMask ,contour_width=Width,contour_color='firebrick')
    word_cloud = wc.generate(' '.join(Text))
    image = word_cloud.to_image()
    plt.imshow(image)
    plt.axis("off")
    plt.title(title)
    plt.show()
    return None

# %%
f = open("/content/ww1.txt", "r",  encoding='utf-8')
Text = f.read()
MakeCloud(' '.join([str(i) for i in Text]))
