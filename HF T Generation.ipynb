# %%
pip install transformers

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, but what I'm really doing is making a human-readable document. There are other languages, but those are"},
#  {'generated_text': "Hello, I'm a language model, not a syntax model. That's why I like it. I've done a lot of programming projects.\n"},
#  {'generated_text': "Hello, I'm a language model, and I'll do it in no time!\n\nOne of the things we learned from talking to my friend"},
# ...

# %%
generator("can I ask you a question", max_length=30, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'can I ask you a question, what is your stance on gay marriage?"\n\nYou are the only person in this room willing to answer that question'},
#  {'generated_text': "can I ask you a question about the history of the 'Black Panthers?' We know very little about them.\n\nNo, they didn't come"},
#  {'generated_text': 'can I ask you a question about this?"\n\n"What does the man know about this?" Nora asked.\n\n"Nothing." Ren stated'},
#  {'generated_text': 'can I ask you a question?\n\nJULIC\n\nNooo. This is a question you asked during our debate. So what would'},
#  {'generated_text': 'can I ask you a question:\n\nWhat to do with her?\n\nTo make them love me instead of hating me.\n\nLet'}]

# %%
generator("Albert Einstein is one of the most", max_length=30, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Albert Einstein is one of the most impressive scientific minds the world has ever seen. In 1819, he published his theory of primes as the idea'},
#  {'generated_text': 'Albert Einstein is one of the most influential thinkers of our time, but still one of the least talked about thinkers of our time. His essays have become'},
#  {'generated_text': 'Albert Einstein is one of the most celebrated physicists of the 20th century. He is known for his theories of quantum mechanics, that of relativity, and'},
#  {'generated_text': 'Albert Einstein is one of the most influential thinkers of the twentieth century. He was able to create his own philosophical framework upon which his work was based.'},
#  {'generated_text': 'Albert Einstein is one of the most famous and acclaimed science fiction writers of all time and yet he is not known for being true to his original ideas.'}]

# %%
generator("Albert Einstein is one of the most", max_length=1000, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
generator("أريد أن أحكي لك عن موضوع هام", max_length=100, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "أريد أن أحكي لك عن موضوع هام! [Hijrah]\n\nI said to the man who has not been eating fish in the morning, 'What will you do with it?' [If someone said something about it, it is done on purpose] And the one who eats it said,\n\n'If there is no fish, it will be the same.'"},
#  {'generated_text': 'أريد أن أحكي لك عن موضوع هامی بنت سرُهن تبد ذلى اللميخ وهورج رمن بمته ل من أمداه يلم بشعیین و'},
#  {'generated_text': 'أريد أن أحكي لك عن موضوع هام ـت لا أغن بإلى يعود هاماللّح و من الله أبحل يجمنا كاند مدولكون النب'},
#  {'generated_text': 'أريد أن أحكي لك عن موضوع هامككنا أفخوا و ، ف مان الله و و هذا أه و ه الدين أدؤ،ين مان بشنيض و إسم ال'},
#  {'generated_text': 'أريد أن أحكي لك عن موضوع هام الأسح أحكي و في أن لظد سكض، ـصـتر لك يتطل مقلوه\n\nTranslation: The Messenger of Allah sent those who'}]

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="akhooli/gpt2-small-arabic")
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/510M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/30.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.55M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.21M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("akhooli/gpt2-small-arabic")
model = AutoModelForCausalLM.from_pretrained("akhooli/gpt2-small-arabic")

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
