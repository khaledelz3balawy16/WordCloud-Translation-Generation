# %%
pip install -U deep_translator
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.1 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
SIA = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
GoogleTranslator(source='ar', target='en').translate('كيف حالك')
# Out:
# 'How are you'

# %%
def T(text) :
  return GoogleTranslator(source='ar', target='en').translate(text)

# %%
T('عامل ايه')
# Out:
# 'what are you doing'

# %%
T('و لست بعلام الغيوب و إنما أري بلحاظ الرأي ما هو واقع')
# Out:
# 'I am not a knower of the unseen, but rather I see from the point of view what is reality'

# %%
T('في مثل هذا اليوم قامت الطائرات اليابانية بهجومٍ مباغت على قاعدة كانوهي العسكرية في شبه جزيرة موكابو، الواقعة على بعد أقل من 15 ميلًا (24 كيلومترًا) شرق ميناء بيرل هاربر في صباح 7 ديسمبر 1941، تكبدت الولايات المتحدة أكبر الخسائر العسكرية في تاريخها على الإطلاق، واضطرت لدخول الحرب العالمية الثانية.')
# Out:
# 'On this day, Japanese aircraft launched a surprise attack on the Kanohe military base on the Mokapu Peninsula, located less than 15 miles (24 kilometers) east of Pearl Harbor. On the morning of December 7, 1941, the United States suffered the largest military losses in its history ever. It was forced to enter World War II.'

# %%
T('ازيك')
# Out:
# 'How are you'

# %%
Values = list(SIA.polarity_scores(T('فيلم زي الزفت بصراحة')).values())

print(f'Value for Negative is    :  {Values[0]}')
print(f'Value for Neutral  is    :  {Values[1]}')
print(f'Value for Positive is    :  {Values[2]}')
print(f'Value for Compound is    :  {Values[3]}')
# Out:
# Value for Negative is    :  0.0
# Value for Neutral  is    :  0.545
# Value for Positive is    :  0.455
# Value for Compound is    :  0.3612

# %%
Values = list(SIA.polarity_scores(T('مطعم رهيييب')).values())

print(f'Value for Negative is    :  {Values[0]}')
print(f'Value for Neutral  is    :  {Values[1]}')
print(f'Value for Positive is    :  {Values[2]}')
print(f'Value for Compound is    :  {Values[3]}')
# Out:
# Value for Negative is    :  0.0
# Value for Neutral  is    :  0.196
# Value for Positive is    :  0.804
# Value for Compound is    :  0.6249

# %%
GoogleTranslator().get_supported_languages(as_dict=True)
# Out:
# {'afrikaans': 'af',
#  'albanian': 'sq',
#  'amharic': 'am',
#  'arabic': 'ar',
#  'armenian': 'hy',
#  'assamese': 'as',
#  'aymara': 'ay',
#  'azerbaijani': 'az',
#  'bambara': 'bm',
#  'basque': 'eu',
#  'belarusian': 'be',
#  'bengali': 'bn',
#  'bhojpuri': 'bho',
#  'bosnian': 'bs',
#  'bulgarian': 'bg',
#  'catalan': 'ca',
#  'cebuano': 'ceb',
#  'chichewa': 'ny',
#  'chinese (simplified)': 'zh-CN',
#  'chinese (traditional)': 'zh-TW',
#  'corsican': 'co',
#  'croatian': 'hr',
#  'czech': 'cs',
#  'danish': 'da',
#  'dhivehi': 'dv',
#  'dogri': 'doi',
#  'dutch': 'nl',
#  'english': 'en',
#  'esperanto': 'eo',
#  'estonian': 'et',
#  'ewe': 'ee',
#  'filipino': 'tl',
#  'finnish': 'fi',
#  'french': 'fr',
#  'frisian': 'fy',
#  'galician': 'gl',
#  'georgian': 'ka',
#  'german': 'de',
#  'greek': 'el',
#  'guarani': 'gn',
#  'gujarati': 'gu',
#  'haitian creole': 'ht',
#  'hausa': 'ha',
#  'hawaiian': 'haw',
#  'hebrew': 'iw',
#  'hindi': 'hi',
#  'hmong': 'hmn',
# ...

# %%
len(GoogleTranslator().get_supported_languages(as_dict=True).keys())
# Out:
# 133

# %%
def TranslateAll(T) :
  for i,k in GoogleTranslator().get_supported_languages(as_dict=True).items() :
    print(f'For Language {i}, translation is ({GoogleTranslator(source="ar", target=k).translate(T)})\n....................\n')
TranslateAll('كيف حالك')
# Out:
# For Language afrikaans, translation is (Hoe gaan dit)
# ....................
#
# For Language albanian, translation is (Si jeni)
# ....................
#
# For Language amharic, translation is (ስላም)
# ....................
#
# For Language arabic, translation is (كيف حالك)
# ....................
#
# For Language armenian, translation is (Ինչպես ես)
# ....................
#
# For Language assamese, translation is (আপোনাৰ কেনে)
# ....................
#
# For Language aymara, translation is (Kamisaraki)
# ....................
#
# For Language azerbaijani, translation is (Necəsən)
# ....................
#
# For Language bambara, translation is (I ka kɛnɛ wa)
# ....................
#
# For Language basque, translation is (Zelan zaude)
# ....................
#
# For Language belarusian, translation is (Як ты)
# ....................
#
# For Language bengali, translation is (আপনি কেমন আছেন)
# ....................
#
# For Language bhojpuri, translation is (का हाल बा)
# ....................
#
# ...
